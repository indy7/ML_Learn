# %%
import numpy as np

# %%
a = np.array([1,3,2,4])

# %%
a

# %%
type(a)

# %%
b = np.array([[8, 5, 6, 1],
[4, 3, 0, 7],
[1, 3, 2, 9]])

# %%
c = np.array([[[1, 2, 3],
[4, 3, 6]],
[[8, 5, 1],
[5, 2, 7]],
[[0, 4, 5],
[8, 9, 1]],
[[1, 2, 6],
[3, 7, 4]]])

# %%
points = np.arange(-5,5,0.01)
xs,ys = np.meshgrid(points,points)
ys
# Out:
# array([[-5.  , -5.  , -5.  , ..., -5.  , -5.  , -5.  ],
#        [-4.99, -4.99, -4.99, ..., -4.99, -4.99, -4.99],
#        [-4.98, -4.98, -4.98, ..., -4.98, -4.98, -4.98],
#        ...,
#        [ 4.97,  4.97,  4.97, ...,  4.97,  4.97,  4.97],
#        [ 4.98,  4.98,  4.98, ...,  4.98,  4.98,  4.98],
#        [ 4.99,  4.99,  4.99, ...,  4.99,  4.99,  4.99]])

# %%
xs
# Out:
# array([[-5.  , -4.99, -4.98, ...,  4.97,  4.98,  4.99],
#        [-5.  , -4.99, -4.98, ...,  4.97,  4.98,  4.99],
#        [-5.  , -4.99, -4.98, ...,  4.97,  4.98,  4.99],
#        ...,
#        [-5.  , -4.99, -4.98, ...,  4.97,  4.98,  4.99],
#        [-5.  , -4.99, -4.98, ...,  4.97,  4.98,  4.99],
#        [-5.  , -4.99, -4.98, ...,  4.97,  4.98,  4.99]])

# %%
z = np.sqrt(xs ** 2 + ys ** 2)

# %%
z[:10,0]
# Out:
# array([7.07106781, 7.06400028, 7.05693985, 7.04988652, 7.04284034,
#        7.0358013 , 7.02876945, 7.0217448 , 7.01472736, 7.00771717])

# %%
ys.shape
# Out:
# (1000, 1000)

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import rcParams
rcParams['figure.figsize'] = (14.5, 9)

# %%
plt.imshow(z, cmap=plt.cm.gray); plt.colorbar()

# %%
arr = np.random.randn(4,4)

# %%
arr
# Out:
# array([[-0.68566534,  0.95070704,  1.34834574,  0.14983349],
#        [ 2.15517387,  1.82404316,  0.38978401,  0.36345351],
#        [ 0.55224559,  0.27624668,  2.17126079, -0.4569664 ],
#        [-0.81398065,  0.25736657, -0.88315096, -1.47626127]])

# %%
np.where(arr > 0, 2, arr)
# Out:
# array([[-0.68566534,  2.        ,  2.        ,  2.        ],
#        [ 2.        ,  2.        ,  2.        ,  2.        ],
#        [ 2.        ,  2.        ,  2.        , -0.4569664 ],
#        [-0.81398065,  2.        , -0.88315096, -1.47626127]])

# %%
arr = np.random.randn(5,4)

# %%
arr
# Out:
# array([[ 0.63712317, -1.17249824, -2.27085147,  0.21807879],
#        [-0.74929083, -0.91754645,  0.05680561, -0.62456531],
#        [-0.78119643,  0.52270161, -0.63489461,  0.5417006 ],
#        [ 0.91208648, -0.9793101 , -1.20049333, -1.78588278],
#        [ 1.41270121, -0.25938594,  1.65120059, -0.96960432]])

# %%
arr.sum(axis=0)
# Out:
# array([ 1.4314236 , -2.80603911, -2.39823321, -2.62027302])

# %%
arr.sum(axis=1)
# Out:
# array([-2.58814775, -2.23459697, -0.35168884, -3.05359973,  1.83491155])

# %%
# Linear Algebra

x = np.array([[1.,2.,3.],[4.,5.,6.]])
y = np.array([[6.,23.],[-1,7],[8,9]])
x
# Out:
# array([[1., 2., 3.],
#        [4., 5., 6.]])

# %%
y
# Out:
# array([[ 6., 23.],
#        [-1.,  7.],
#        [ 8.,  9.]])

# %%
x.dot(y)
# Out:
# array([[ 28.,  64.],
#        [ 67., 181.]])

# %%
from numpy.linalg import inv, qr
X = np.random.randn(5,5)
X
# Out:
# array([[ 0.48895161,  0.90787766,  0.57662894, -0.30218864,  1.04930144],
#        [ 0.61956983,  0.38591836, -1.34288998, -0.42712337, -0.88563348],
#        [ 0.4532478 , -0.45142261, -0.80405696, -1.27378277,  0.90989386],
#        [ 1.07287749,  2.79063526,  0.64946933,  0.12204291,  0.95122322],
#        [-0.35291822, -0.71187901, -1.78927062,  0.02099363, -1.0222339 ]])

# %%
mat = X.T.dot(X)
inv(mat)
# Out:
# array([[ 4007.13962286, -1981.12561704,  -711.39447237,  3523.97363375,
#          1304.75449395],
#        [-1981.12561704,   979.66757797,   351.91330572, -1742.65769379,
#          -645.462738  ],
#        [ -711.39447237,   351.91330572,   127.66169798,  -627.55220565,
#          -233.23431034],
#        [ 3523.97363375, -1742.65769379,  -627.55220565,  3102.48624999,
#          1149.93832218],
#        [ 1304.75449395,  -645.462738  ,  -233.23431034,  1149.93832218,
#           427.09715164]])

# %%
samples = np.random.normal(size=(4,4))
samples
# Out:
# array([[ 0.38063254, -0.3555125 ,  0.11474449, -1.65528477],
#        [-0.50796674,  0.12819483,  0.81564024, -0.18983262],
#        [-1.62803473,  1.12977647,  0.5876348 ,  0.9780028 ],
#        [ 0.07359906,  0.51355218, -1.13037658,  0.4223316 ]])

# %%
from random import normalvariate

# %%
N = 1000000

# %%
# %timeit samples = [normalvariate(0,1) for _ in range(N)]
# Out:
# 1.58 s ± 44 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit np.random.normal(size=N)
# Out:
# 45.8 ms ± 2.46 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# Random Walks

import random
position = 0
walk = [position]
steps = 1000
for i in range(steps):
  step = 1 if random.randint(0,1) else -1
  position += step
  walk.append(position)

# %%
plt.plot(walk[:100])
